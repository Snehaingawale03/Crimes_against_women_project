# %% [markdown]
# # ---------CRIMES_AGAINST_WOMEN_DURING_2001-2012---------

# %%
# importing all the necessaary libaries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Crimes project data.csv')
data
# Out:
#            STATE/UT  Year  RAPE  KIDNAPPING & ABDUCTION  DOWRY DEATH  \
# 0    Andhra Pradesh  2001   871                     765          420
# 1    Andhra Pradesh  2002  1002                     854          449
# 2    Andhra Pradesh  2003   946                     931          466
# 3    Andhra Pradesh  2004  1016                    1030          512
# 4    Andhra Pradesh  2005   935                     995          443
# ..              ...   ...   ...                     ...          ...
# 415      Puducherry  2008     8                       9            2
# 416      Puducherry  2009     1                      13            0
# 417      Puducherry  2010     3                      14            1
# 418      Puducherry  2011     7                       9            1
# 419      Puducherry  2012    13                      16            0
#
#      ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 0                                                 3544
# 1                                                 3799
# 2                                                 4128
# 3                                                 3817
# 4                                                 3595
# ..                                                 ...
# 415                                                 65
# 416                                                 53
# 417                                                 46
# 418                                                 35
# 419                                                  9
#
#      INSULT TO THE MODESTY OF WOMEN  CRUELTY BY HUSBAND OR RELATIVES  \
# 0                              2271                             5791
# 1                              2024                             7018
# 2                              2286                             8167
# 3                              2310                             8388
# 4                              2508                             8696
# ..                              ...                              ...
# 415                              21                               12
# 416                              16                               10
# 417                              22                                7
# 418                              16                               10
# 419                               2                                6
#
#      IMMORAL TRAFFIC(PREVENTION)ACT  \
# 0                              1332
# 1                               871
# 2                               349
# 3                               405
# 4                               681
# ..                              ...
# 415                               3
# 416                               9
# 417                              11
# 418                               3
# 419                               4
#
#      INDECENT REPRESENTATION OF WOMEN(PREVENTION)ACT  \
# 0                                                925
# 1                                               2403
# 2                                                909
# 3                                               1102
# 4                                               2657
# ..                                               ...
# 415                                                0
# 416                                                0
# 417                                                0
# 418                                                0
# 419                                                0
#
#      TOTAL CRIMES AGAINST WOMEN
# 0                         16477
# 1                         18880
# 2                         18382
# 3                         18921
# 4                         20819
# ..                          ...
# 415                         129
# 416                         106
# 417                         115
# 418                          89
# 419                          61
#
# [420 rows x 11 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 11 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             420 non-null    object
#  1   Year                                                 420 non-null    int64
#  2   RAPE                                                 420 non-null    int64
#  3   KIDNAPPING & ABDUCTION                               420 non-null    int64
#  4   DOWRY DEATH                                          420 non-null    int64
#  5   ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  420 non-null    int64
#  6   INSULT TO THE MODESTY OF WOMEN                       420 non-null    int64
#  7   CRUELTY BY HUSBAND OR RELATIVES                      420 non-null    int64
#  8   IMMORAL TRAFFIC(PREVENTION)ACT                       420 non-null    int64
#  9   INDECENT REPRESENTATION OF WOMEN(PREVENTION)ACT      420 non-null    int64
#  10  TOTAL CRIMES AGAINST WOMEN                           420 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 36.2+ KB

# %%
data1['TOTAL CRIMES AGAINST WOMEN'].sum()
# Out:
# 2173559

# %%
crime_in_years_df = data.groupby('Year').sum()
crime_in_years_df.reset_index(inplace=True)
crime_in_years_df
# Out:
#     Year   RAPE  KIDNAPPING & ABDUCTION  DOWRY DEATH  \
# 0   2001  16396                   14645         6851
# 1   2002  16799                   14506         6822
# 2   2003  16290                   13296         6208
# 3   2004  18691                   15578         7026
# 4   2005  18768                   15750         6787
# 5   2006  19616                   17414         7618
# 6   2007  21103                   20416         8093
# 7   2008  21836                   22939         8172
# 8   2009  21803                   25741         8383
# 9   2010  22620                   29795         8391
# 10  2011  24678                   35565         8618
# 11  2012  25431                   38262         8233
#
#     ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 0                                               34124
# 1                                               33943
# 2                                               32939
# 3                                               34567
# 4                                               34175
# 5                                               36617
# 6                                               38734
# 7                                               40413
# 8                                               38711
# 9                                               40613
# 10                                              42968
# 11                                              45351
#
#     INSULT TO THE MODESTY OF WOMEN  CRUELTY BY HUSBAND OR RELATIVES  \
# 0                             9670                            49170
# 1                            10058                            49237
# 2                            12243                            50703
# 3                             9947                            58121
# 4                             9949                            58319
# 5                             9972                            63128
# 6                            10937                            75930
# 7                            12193                            81344
# 8                            11028                            89546
# 9                             9894                            94041
# 10                            8496                            99135
# 11                            9083                           106527
#
#     IMMORAL TRAFFIC(PREVENTION)ACT  \
# 0                             8796
# 1                             6598
# 2                             5510
# 3                             5748
# 4                             5908
# 5                             4541
# 6                             3568
# 7                             2660
# 8                             2474
# 9                             2499
# 10                            2436
# 11                            2563
#
#     INDECENT REPRESENTATION OF WOMEN(PREVENTION)ACT  \
# 0                                              1052
# 1                                              2508
# 2                                              1043
# 3                                              1378
# 4                                              2917
# 5                                              1562
# 6                                              1200
# 7                                              1025
# 8                                               845
# 9                                               895
# 10                                              453
# 11                                              141
#
#     TOTAL CRIMES AGAINST WOMEN
# 0                       143795
# 1                       143034
# 2                       140601
# 3                       154333
# 4                       155553
# 5                       164765
# 6                       185312
# 7                       195857
# 8                       203804
# 9                       213585
# 10                      228650
# 11                      244270

# %% [markdown]
# # Total crimes against women during 2001-2012

# %%
plt.plot(crime_in_years_df['Year'], crime_in_years_df['TOTAL CRIMES AGAINST WOMEN'], color='red', marker='*')
plt.title('Total crimes against women in India')
plt.xlabel('Years', fontsize = 12)
plt.ylabel("Count of Crime Cases", fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# ###### There is a steady change in crime during 2006-2007. This is also shows that number of crimes against women is increasing at a huge rate

# %% [markdown]
# ## Analysis of crime rates in different states

# %%
plt.figure(figsize=(18,6))
df3=data.groupby('STATE/UT')['TOTAL CRIMES AGAINST WOMEN'].sum().sort_values(ascending=False)
plt.plot(df3,marker='o',color='orange',linewidth=4,markersize=7,markerfacecolor='blue')
plt.xticks(rotation='vertical')
plt.xlabel('STATE/UT')
plt.ylabel('TOTAL CRIMES AGAINST WOMEN')
plt.title('TOTAL CRIMES AGAINST WOMEN BY STATE')
plt.show()

# %% [markdown]
# * "Andhra Pradesh" has the highest number of crime cases.
# * "Uttar Pradesh" is the second highest.
# * "Lakshadweep" has the lowest crime rate.

# %% [markdown]
# ## Percentage of each crime in between 2001-2012 through line graph

# %%
plt.figure(figsize=(12,10))
plt.plot(crime_in_years_df['Year'], crime_in_years_df['RAPE'], color='red', marker = '.',markersize=8,linewidth=4)
plt.plot(crime_in_years_df['Year'], crime_in_years_df['KIDNAPPING & ABDUCTION'], color='blue', marker = 'o',markersize=7,linewidth=4)
plt.plot(crime_in_years_df['Year'], crime_in_years_df['DOWRY DEATH'], color='green', marker = 'o',markersize=8,linewidth=4)
plt.plot(crime_in_years_df['Year'], crime_in_years_df['ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY'], color='cyan', marker = 'x',markersize=8,linewidth=4)
plt.plot(crime_in_years_df['Year'], crime_in_years_df['INSULT TO THE MODESTY OF WOMEN'], color='orange', marker = '4',markersize=10,linewidth=4)
plt.plot(crime_in_years_df['Year'], crime_in_years_df['CRUELTY BY HUSBAND OR RELATIVES'], color='purple', marker = '*',markersize=8,linewidth=4)
plt.plot(crime_in_years_df['Year'], crime_in_years_df['IMMORAL TRAFFIC(PREVENTION)ACT'], color='skyblue', marker = 's',markersize=8,linewidth=4)
plt.title("yearly crime cases against Women")
plt.xlabel("Years")
plt.ylabel("Sprade Of Cases")
plt.legend(['RAPE', 'KIDNAPPING & ABDUCTION', 'DOWRY DEATH',
       'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
       'INSULT TO THE MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR RELATIVES',
       'IMMORAL TRAFFIC(PREVENTION)ACT'], loc = 'center left', bbox_to_anchor=(1, 0.5))
plt.grid(True)
plt.show()

# %% [markdown]
# - As per above chart almost 40% rape cases are increased from 2001 to 2012. but in 2003 we can see
#   that rape cases were decreased than the years of 2001 and 2002.
# * Kidnapping and abduction cases were registered in 2012 was triples than 2001.
#   In 2003 cases of Kidnapping was decreased.
# * Dowry Deaths Cases were decreased in 2012 with the comparison of the 2001.
#   most decreased cases were registered in 2003.
# * here,Insult to modesty of women crime cases were registered highly in the year 2003.
# * Even in the 21st century, society doesn't know how to treat and respect women at home. The Domestic   Violence cases were 60% more in 2012 than in 2001.
# * "importance of Girls" is the only crime which had reduced considerably. but still it needs to
#    improve.

# %% [markdown]
# ## Analysis of kidnapping and abduction crime reports on year 2012 in  different states .

# %%
df4=data[data['Year']== 2012]
plt.figure(figsize=(18,6))
plt.bar(df4['STATE/UT'],df4['KIDNAPPING & ABDUCTION'],color='purple')
plt.xticks(rotation='vertical')
plt.xlabel('STATE/UT')
plt.ylabel('KIDNAPPING & ABDUCTION')
plt.title('KIDNAPPING & ABDUCTION ON YEAR 2012')
plt.show()

# %% [markdown]
#  ####  As per the above graph kidnapping and abduction cases was highly reported in uttar pradesh.

# %% [markdown]
# ## To Find Which was highest reported crime and which one was least through pie - chart

# %%
# use "drop" for remove "Total Number Of Cases" column:

crime_df = crime_in_years_df.drop("TOTAL CRIMES AGAINST WOMEN", axis=1)
crime_df.set_index("Year", inplace = True)

# %%
# let's sort the values of the total count of the crime. 

Total_crime_df = pd.DataFrame(crime_df.sum(axis=0), columns = ['Count']).sort_values(by='Count', ascending=False)
Total_crime_df
# Out:
#                                                      Count
# CRUELTY BY HUSBAND OR RELATIVES                     875201
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...  453155
# KIDNAPPING & ABDUCTION                              263907
# RAPE                                                244031
# INSULT TO THE MODESTY OF WOMEN                      123470
# DOWRY DEATH                                          91202
# IMMORAL TRAFFIC(PREVENTION)ACT                       53301
# INDECENT REPRESENTATION OF WOMEN(PREVENTION)ACT      15019

# %%
dataframe = pd.DataFrame({'Crime':['RAPE', 'KIDNAPPING & ABDUCTION', 'DOWRY DEATH',
       'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
       'INSULT TO THE MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR RELATIVES',
       'IMMORAL TRAFFIC(PREVENTION)ACT','INDECENT REPRESENTATION OF WOMEN(PREVENTION)ACT'],
                         'Count':[244031,263907,91202,453155,123470,875201,53301,15019]})

# Defining colors for the pie chart:
colors = ["pink", "red", "steelblue", "red", "orange",
         "indigo", "violet","orange"]

explode = (0.0, 0.1, 0.0, 0.2, 0.3, 0.0, 0.0,0.0)

dataframe.groupby(['Crime']).sum().plot(
kind = 'pie', y = 'Count',
autopct='%1.0f%%',
colors = colors, explode= explode, figsize=(15,10))
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# #### Domestic Violence is the highest reported crime and Importation of Girls is least reported crime.

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Linear Regression :

# %%
import warnings
from sklearn import linear_model
from sklearn.model_selection import train_test_split
warnings.simplefilter(action="ignore", category=FutureWarning)
# %matplotlib inline

# %% [markdown]
# #  --------------   Kidnapping & Abduction Cases     ---------------------

# %% [markdown]
# ### before prediction "Kidnapping & Abduction" cases intercept and coefficient values:

# %%
xs1 = crime_in_years_df.iloc[:, 0]
ys1 = crime_in_years_df.iloc[:, 2]

X_train1, X_test1, y_train1, y_test1 = train_test_split(xs1, ys1, test_size=0.3, random_state=0)
print(str(X_train1) + "\n\n" + str(y_train1))
# Out:
# 2    2003
# 8    2009
# 1    2002
# 7    2008
# 9    2010
# 3    2004
# 0    2001
# 5    2006
# Name: Year, dtype: int64
#
# 2    13296
# 8    25741
# 1    14506
# 7    22939
# 9    29795
# 3    15578
# 0    14645
# 5    17414
# Name: KIDNAPPING & ABDUCTION, dtype: int64

# %%
plt.scatter(X_train1, y_train1)
plt.ylabel("Kidnapping & Abduction Crime Reate")
plt.xlabel("Year")
plt.show()

# %%
# intercept caluculation:

def slope_intercept(x_val, y_val):
    """ calculation of intercept"""
    x = np.array(x_val)
    y = np.array(y_val)
    m = (((np.mean(x) * np.mean(y)) - np.mean(x*y)) /
    ((np.mean(x) * np.mean(x)) - np.mean(x*x)))
    m = round(m,2)
    b = (np.mean(y) - np.mean(x) * m)
    b = round(b,2)
    
    return m, b
slope_intercept(xs1, ys1)
# Out:
# (2238.44, -4469437.61)

# %%
# making regression line:

m1, b1 = slope_intercept(xs1, ys1)
reg_line = [(m1 * x) + b1 for x in xs1]
plt.scatter(xs1, ys1, color = "green")
plt.plot(xs1, reg_line)
plt.ylabel("Kidnapping & Abduction Crime Rate")
plt.xlabel("Year")
plt.title("Regression line for Kidnapping & Abduction")
plt.show()

# %%
print("Regression Intercept: " + str(m1))
print("Regression Coefficient: " + str(b1))
# Out:
# Regression Intercept: 2238.44
# Regression Coefficient: -4469437.61

# %%
print("Year")

for x in np.nditer(xs1):
    print(x)
    
print("\n\nKidnapping & Abduction")

for x in np.nditer(ys1):
    print(x)
# Out:
# Year
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
#
#
# Kidnapping & Abduction
# 14645
# 14506
# 13296
# 15578
# 15750
# 17414
# 20416
# 22939
# 25741
# 29795
# 35565
# 38262

# %% [markdown]
# ## prediction of next five years for "Kidnapping & Abduction" crime column:

# %%
years = np.array([2013,2014, 2015, 2016, 2017, 2018])
predict_crime_in_years1 = pd.DataFrame(years)
print(predict_crime_in_years1)

ypred_ = (m1 * years + b1)

print("Predicted Kidnapping Rate")

for x in np.nditer(ypred_):
    print(int(x))
# Out:
#       0
# 0  2013
# 1  2014
# 2  2015
# 3  2016
# 4  2017
# 5  2018
# Predicted Kidnapping Rate
# 36542
# 38780
# 41018
# 43257
# 45495
# 47734

# %% [markdown]
# * here, we found predicted "kidnapping and abduction" values from 2013 to 2018.
# * so, we can visualize linear regression line for "Kidnapping & Abduction" from 2001 to 2018.

# %%
# merging the values and year with predicted values and year.

merge_list1 = np.concatenate((xs1, years), axis=0)
print("Years: " + str(merge_list1))


reg_line = [(m1*x)+b1 for x in merge_list1]

transform_list1 = np.concatenate((ys1, ypred_), axis=0)
print("Kidnapping & Abduction: "+str(transform_list1))

fig = plt.figure(figsize=(15,12))
plt.scatter(merge_list1, transform_list1, color = "Green")
plt.plot(merge_list1, reg_line)
plt.xlim((2001, 2018))
plt.ylabel("Kidnapping & Abduction Crime Rate")
plt.xlabel("Years")
plt.title("Kidnapping & abduction Crime regression Line from 2001 to 2018")
plt.show()
# Out:
# Years: [2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
#  2015 2016 2017 2018]
# Kidnapping & Abduction: [14645.   14506.   13296.   15578.   15750.   17414.   20416.   22939.
#  25741.   29795.   35565.   38262.   36542.11 38780.55 41018.99 43257.43
#  45495.87 47734.31]

# %% [markdown]
# #### There are several actions that can be taken to decrease Kidnapping and Abduction crime rates such   as Use of technology. Implement surveillance cameras, drones, and other technology to monitor public spaces and gather evidence for investigations.

# %% [markdown]
# ### ----------------  Cruelty by Husband or his Relatives -----------------------------

# %%
xs5 = crime_in_years_df.iloc[:,0]
ys5 = crime_in_years_df.iloc[:,6]

X_train5, X_test5, y_train5, y_test5 = train_test_split(xs5, ys5, test_size=0.3, random_state=0) 
print(str(X_train5)+"\n\n"+str(y_train5))
# Out:
# 2    2003
# 8    2009
# 1    2002
# 7    2008
# 9    2010
# 3    2004
# 0    2001
# 5    2006
# Name: Year, dtype: int64
#
# 2    50703
# 8    89546
# 1    49237
# 7    81344
# 9    94041
# 3    58121
# 0    49170
# 5    63128
# Name: CRUELTY BY HUSBAND OR RELATIVES, dtype: int64

# %%
plt.scatter(xs5,ys5)
plt.ylabel("Cruelty by Husband or his Relatives ")
plt.xlabel("Year")
plt.show()

# %%
slope_intercept(xs5,ys5)
# Out:
# (5672.65, -11309238.81)

# %%
m5,b5=slope_intercept(xs5,ys5)
reg_line=[(m5*x)+b5 for x in xs5]

fig = plt.figure(figsize=(12,10))
plt.scatter(xs5,ys5,color="green")
plt.plot(xs5,reg_line)
plt.ylabel("Cruelty by Husband or his Relatives crime rate")
plt.xlabel("Year")
plt.title("before prediction a regression line of cruelty by Husband/relatives")
# Out:
# Text(0.5, 1.0, 'before prediction a regression line of cruelty by Husband/relatives')

# %%
print("Regressor intercept: "+str(m5) )
print("Regressor coefficient: "+str(b5) )
# Out:
# Regressor intercept: 5672.65
# Regressor coefficient: -11309238.81

# %%
print("Year")
for x in np.nditer(xs5):
  print(x)
print("\n\n Cruelty by Husband or his Relatives crime values")
for x in np.nditer(ys5):
  print(x)
# Out:
# Year
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
#
#
#  Cruelty by Husband or his Relatives crime values
# 49170
# 49237
# 50703
# 58121
# 58319
# 63128
# 75930
# 81344
# 89546
# 94041
# 99135
# 106527

# %% [markdown]
# ### Prediction of next years for "Cruelty by Husband or his Relatives" column:

# %%
years = np.array([2013,2014,2015,2016,2017,2018])
predict_crime_in_years5 = pd.DataFrame(years)
print(predict_crime_in_years5)
ypredd5 = (m5 * years + b5)

print("Predicted Values of Cruelty by Husband/relatives")
for x in np.nditer(ypredd5):
  print(int(x))
# Out:
#       0
# 0  2013
# 1  2014
# 2  2015
# 3  2016
# 4  2017
# 5  2018
# Predicted Values of Cruelty by Husband/relatives
# 109805
# 115478
# 121150
# 126823
# 132496
# 138168

# %%
# merging the values and year with predicted values and year.

merge_list5 = np.concatenate((xs5, years), axis=0)
print("Years: " + str(merge_list5))


reg_line = [(m5 * x) + b5 for x in merge_list5]

transform_list5 = np.concatenate((ys5, ypredd5), axis=0)
print("Cruelty by Husband/relatives: "+str(transform_list5))

fig = plt.figure(figsize=(15,12))
plt.scatter(merge_list5, transform_list5, color = "brown")
plt.plot(merge_list5, reg_line)
plt.xlim((2001, 2018))
plt.ylabel("Cruelty by Husband/relaties Crime Rate")
plt.xlabel("Years")
plt.title("Predicted values of cruelty by husband/relatives regression Line from 2001 to 2018")
plt.show()
# Out:
# Years: [2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
#  2015 2016 2017 2018]
# Cruelty by Husband/relatives: [ 49170.    49237.    50703.    58121.    58319.    63128.    75930.
#   81344.    89546.    94041.    99135.   106527.   109805.64 115478.29
#  121150.94 126823.59 132496.24 138168.89]

# %% [markdown]
# #### In various states, several actions can be taken to decrease crime rates. Here are some general strategies that can be appiled across different states :
# -  Targeted Policing
# -  Use of technology
# -  Social programs
# -  Public Awareness
# -  Crime prevention programs
